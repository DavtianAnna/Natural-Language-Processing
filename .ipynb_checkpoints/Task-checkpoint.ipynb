# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')

# %%
df_train.head()
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df_test.head()
# Out:
#    id keyword location                                               text
# 0   0     NaN      NaN                 Just happened a terrible car crash
# 1   2     NaN      NaN  Heard about #earthquake is different cities, s...
# 2   3     NaN      NaN  there is a forest fire at spot pond, geese are...
# 3   9     NaN      NaN           Apocalypse lighting. #Spokane #wildfires
# 4  11     NaN      NaN      Typhoon Soudelor kills 28 in China and Taiwan

# %% [markdown]
# # TfidfVectorizer + GridSearchCV

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from xgboost import XGBClassifier
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report

# %%
X = df_train['text']
y = df_train['target']

# %%
tfidf = TfidfVectorizer()
model = XGBClassifier()

# %%
pipe = Pipeline([('tfidf', tfidf), ('model', model)])

# %%
params = {
    'model__n_estimators': [100, 200, 250, 300],
    'model__max_depth': [3, 5, 7, 11, 13],
    'model__learning_rate': [0.1, 0.01, 0.3]
}

# %%
final_model = GridSearchCV(pipe, param_grid = params, cv= 3, verbose = 2 )

# %%
final_model.fit(X, y)
# Out:
# Fitting 3 folds for each of 60 candidates, totalling 180 fits
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=100; total time=   2.9s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=100; total time=   2.7s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=100; total time=   2.2s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=200; total time=   4.6s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=200; total time=   4.5s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=200; total time=   4.0s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=250; total time=   5.8s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=250; total time=   5.4s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=250; total time=   4.8s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=300; total time=   6.5s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=300; total time=   6.4s
# [CV] END model__learning_rate=0.1, model__max_depth=3, model__n_estimators=300; total time=   5.7s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=100; total time=   4.3s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=100; total time=   4.3s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=100; total time=   4.1s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200; total time=   7.7s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200; total time=   7.5s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200; total time=   7.8s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=250; total time=   9.5s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=250; total time=   9.0s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=250; total time=   8.9s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=300; total time=  11.2s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=300; total time=  10.8s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=300; total time=  10.7s
# [CV] END model__learning_rate=0.1, model__max_depth=7, model__n_estimators=100; total time=   8.4s
# [CV] END model__learning_rate=0.1, model__max_depth=7, model__n_estimators=100; total time=   6.6s
# [CV] END model__learning_rate=0.1, model__max_depth=7, model__n_estimators=100; total time=   6.6s
# [CV] END model__learning_rate=0.1, model__max_depth=7, model__n_estimators=200; total time=  11.4s
# [CV] END model__learning_rate=0.1, model__max_depth=7, model__n_estimators=200; total time=  11.1s
# [CV] END model__learning_rate=0.1, model__max_depth=7, model__n_estimators=200; total time=  11.2s
# [CV] END model__learning_rate=0.1, model__max_depth=7, model__n_estimators=250; total time=  14.1s
# [CV] END model__learning_rate=0.1, model__max_depth=7, model__n_estimators=250; total time=  13.5s
# [CV] END model__learning_rate=0.1, model__max_depth=7, model__n_estimators=250; total time=  13.0s
# [CV] END model__learning_rate=0.1, model__max_depth=7, model__n_estimators=300; total time=  20.8s
# [CV] END model__learning_rate=0.1, model__max_depth=7, model__n_estimators=300; total time=  15.8s
# [CV] END model__learning_rate=0.1, model__max_depth=7, model__n_estimators=300; total time=  15.6s
# [CV] END model__learning_rate=0.1, model__max_depth=11, model__n_estimators=100; total time=  11.5s
# [CV] END model__learning_rate=0.1, model__max_depth=11, model__n_estimators=100; total time=  10.7s
# [CV] END model__learning_rate=0.1, model__max_depth=11, model__n_estimators=100; total time=  13.1s
# [CV] END model__learning_rate=0.1, model__max_depth=11, model__n_estimators=200; total time=  19.7s
# [CV] END model__learning_rate=0.1, model__max_depth=11, model__n_estimators=200; total time=  18.1s
# [CV] END model__learning_rate=0.1, model__max_depth=11, model__n_estimators=200; total time=  19.0s
# [CV] END model__learning_rate=0.1, model__max_depth=11, model__n_estimators=250; total time=  24.2s
# [CV] END model__learning_rate=0.1, model__max_depth=11, model__n_estimators=250; total time=  28.8s
# [CV] END model__learning_rate=0.1, model__max_depth=11, model__n_estimators=250; total time=  44.3s
# [CV] END model__learning_rate=0.1, model__max_depth=11, model__n_estimators=300; total time=  38.9s
# [CV] END model__learning_rate=0.1, model__max_depth=11, model__n_estimators=300; total time=  32.0s
# [CV] END model__learning_rate=0.1, model__max_depth=11, model__n_estimators=300; total time=  30.5s
# [CV] END model__learning_rate=0.1, model__max_depth=13, model__n_estimators=100; total time=  18.5s
# [CV] END model__learning_rate=0.1, model__max_depth=13, model__n_estimators=100; total time=  14.6s
# [CV] END model__learning_rate=0.1, model__max_depth=13, model__n_estimators=100; total time=  18.9s
# [CV] END model__learning_rate=0.1, model__max_depth=13, model__n_estimators=200; total time=  32.6s
# [CV] END model__learning_rate=0.1, model__max_depth=13, model__n_estimators=200; total time=  37.3s
# [CV] END model__learning_rate=0.1, model__max_depth=13, model__n_estimators=200; total time=  30.7s
# [CV] END model__learning_rate=0.1, model__max_depth=13, model__n_estimators=250; total time=  46.4s
# [CV] END model__learning_rate=0.1, model__max_depth=13, model__n_estimators=250; total time=  35.9s
# [CV] END model__learning_rate=0.1, model__max_depth=13, model__n_estimators=250; total time=  36.4s
# [CV] END model__learning_rate=0.1, model__max_depth=13, model__n_estimators=300; total time=  38.3s
# [CV] END model__learning_rate=0.1, model__max_depth=13, model__n_estimators=300; total time=  34.9s
# [CV] END model__learning_rate=0.1, model__max_depth=13, model__n_estimators=300; total time=  39.9s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100; total time=   3.3s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100; total time=   2.8s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=100; total time=   2.6s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200; total time=   7.7s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200; total time=   9.5s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=200; total time=   4.9s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=250; total time=   8.0s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=250; total time=   9.9s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=250; total time=  16.2s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=300; total time=   8.8s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=300; total time=   8.4s
# [CV] END model__learning_rate=0.01, model__max_depth=3, model__n_estimators=300; total time=   8.8s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100; total time=   7.3s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100; total time=   6.9s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=100; total time=  11.0s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=200; total time=  16.3s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=200; total time=  24.2s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=200; total time=  12.5s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=250; total time=  15.6s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=250; total time=  15.1s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=250; total time=  19.6s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=300; total time=  19.8s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=300; total time=  29.7s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=300; total time=  16.0s
# [CV] END model__learning_rate=0.01, model__max_depth=7, model__n_estimators=100; total time=  17.6s
# [CV] END model__learning_rate=0.01, model__max_depth=7, model__n_estimators=100; total time=  19.0s
# [CV] END model__learning_rate=0.01, model__max_depth=7, model__n_estimators=100; total time=  15.1s
# [CV] END model__learning_rate=0.01, model__max_depth=7, model__n_estimators=200; total time=  21.7s
# [CV] END model__learning_rate=0.01, model__max_depth=7, model__n_estimators=200; total time=  30.6s
# [CV] END model__learning_rate=0.01, model__max_depth=7, model__n_estimators=200; total time=  37.7s
# [CV] END model__learning_rate=0.01, model__max_depth=7, model__n_estimators=250; total time=  40.6s
# [CV] END model__learning_rate=0.01, model__max_depth=7, model__n_estimators=250; total time=  47.1s
# [CV] END model__learning_rate=0.01, model__max_depth=7, model__n_estimators=250; total time=  28.0s
# [CV] END model__learning_rate=0.01, model__max_depth=7, model__n_estimators=300; total time=  33.0s
# [CV] END model__learning_rate=0.01, model__max_depth=7, model__n_estimators=300; total time=  44.5s
# [CV] END model__learning_rate=0.01, model__max_depth=7, model__n_estimators=300; total time=  30.8s
# [CV] END model__learning_rate=0.01, model__max_depth=11, model__n_estimators=100; total time=  22.9s
# [CV] END model__learning_rate=0.01, model__max_depth=11, model__n_estimators=100; total time=  18.6s
# [CV] END model__learning_rate=0.01, model__max_depth=11, model__n_estimators=100; total time=  23.4s
# [CV] END model__learning_rate=0.01, model__max_depth=11, model__n_estimators=200; total time=  36.9s
# [CV] END model__learning_rate=0.01, model__max_depth=11, model__n_estimators=200; total time=  35.6s
# [CV] END model__learning_rate=0.01, model__max_depth=11, model__n_estimators=200; total time=  43.2s
# [CV] END model__learning_rate=0.01, model__max_depth=11, model__n_estimators=250; total time=  39.0s
# [CV] END model__learning_rate=0.01, model__max_depth=11, model__n_estimators=250; total time=  37.5s
# [CV] END model__learning_rate=0.01, model__max_depth=11, model__n_estimators=250; total time=  43.5s
# [CV] END model__learning_rate=0.01, model__max_depth=11, model__n_estimators=300; total time=  44.0s
# [CV] END model__learning_rate=0.01, model__max_depth=11, model__n_estimators=300; total time=  43.1s
# [CV] END model__learning_rate=0.01, model__max_depth=11, model__n_estimators=300; total time=  47.5s
# [CV] END model__learning_rate=0.01, model__max_depth=13, model__n_estimators=100; total time=  27.4s
# [CV] END model__learning_rate=0.01, model__max_depth=13, model__n_estimators=100; total time=  26.5s
# [CV] END model__learning_rate=0.01, model__max_depth=13, model__n_estimators=100; total time=  28.3s
# [CV] END model__learning_rate=0.01, model__max_depth=13, model__n_estimators=200; total time=  42.1s
# [CV] END model__learning_rate=0.01, model__max_depth=13, model__n_estimators=200; total time=  40.0s
# [CV] END model__learning_rate=0.01, model__max_depth=13, model__n_estimators=200; total time=  46.3s
# [CV] END model__learning_rate=0.01, model__max_depth=13, model__n_estimators=250; total time=  48.9s
# [CV] END model__learning_rate=0.01, model__max_depth=13, model__n_estimators=250; total time=  46.0s
# [CV] END model__learning_rate=0.01, model__max_depth=13, model__n_estimators=250; total time=  53.8s
# [CV] END model__learning_rate=0.01, model__max_depth=13, model__n_estimators=300; total time=  55.5s
# [CV] END model__learning_rate=0.01, model__max_depth=13, model__n_estimators=300; total time=  52.7s
# [CV] END model__learning_rate=0.01, model__max_depth=13, model__n_estimators=300; total time=  59.5s
# [CV] END model__learning_rate=0.3, model__max_depth=3, model__n_estimators=100; total time=   2.2s
# [CV] END model__learning_rate=0.3, model__max_depth=3, model__n_estimators=100; total time=   2.1s
# [CV] END model__learning_rate=0.3, model__max_depth=3, model__n_estimators=100; total time=   1.9s
# [CV] END model__learning_rate=0.3, model__max_depth=3, model__n_estimators=200; total time=   4.0s
# [CV] END model__learning_rate=0.3, model__max_depth=3, model__n_estimators=200; total time=   3.9s
# [CV] END model__learning_rate=0.3, model__max_depth=3, model__n_estimators=200; total time=   3.3s
# [CV] END model__learning_rate=0.3, model__max_depth=3, model__n_estimators=250; total time=   4.8s
# [CV] END model__learning_rate=0.3, model__max_depth=3, model__n_estimators=250; total time=   5.2s
# [CV] END model__learning_rate=0.3, model__max_depth=3, model__n_estimators=250; total time=   4.0s
# [CV] END model__learning_rate=0.3, model__max_depth=3, model__n_estimators=300; total time=   5.7s
# [CV] END model__learning_rate=0.3, model__max_depth=3, model__n_estimators=300; total time=   5.8s
# [CV] END model__learning_rate=0.3, model__max_depth=3, model__n_estimators=300; total time=   4.6s
# [CV] END model__learning_rate=0.3, model__max_depth=5, model__n_estimators=100; total time=   3.7s
# [CV] END model__learning_rate=0.3, model__max_depth=5, model__n_estimators=100; total time=   3.8s
# [CV] END model__learning_rate=0.3, model__max_depth=5, model__n_estimators=100; total time=   3.6s
# [CV] END model__learning_rate=0.3, model__max_depth=5, model__n_estimators=200; total time=   6.8s
# [CV] END model__learning_rate=0.3, model__max_depth=5, model__n_estimators=200; total time=   6.7s
# [CV] END model__learning_rate=0.3, model__max_depth=5, model__n_estimators=200; total time=   6.2s
# [CV] END model__learning_rate=0.3, model__max_depth=5, model__n_estimators=250; total time=   8.9s
# [CV] END model__learning_rate=0.3, model__max_depth=5, model__n_estimators=250; total time=   8.1s
# [CV] END model__learning_rate=0.3, model__max_depth=5, model__n_estimators=250; total time=   7.4s
# [CV] END model__learning_rate=0.3, model__max_depth=5, model__n_estimators=300; total time=  10.2s
# [CV] END model__learning_rate=0.3, model__max_depth=5, model__n_estimators=300; total time=   9.7s
# [CV] END model__learning_rate=0.3, model__max_depth=5, model__n_estimators=300; total time=   8.5s
# [CV] END model__learning_rate=0.3, model__max_depth=7, model__n_estimators=100; total time=   5.6s
# [CV] END model__learning_rate=0.3, model__max_depth=7, model__n_estimators=100; total time=   5.3s
# [CV] END model__learning_rate=0.3, model__max_depth=7, model__n_estimators=100; total time=   5.6s
# [CV] END model__learning_rate=0.3, model__max_depth=7, model__n_estimators=200; total time=  10.1s
# [CV] END model__learning_rate=0.3, model__max_depth=7, model__n_estimators=200; total time=   9.7s
# [CV] END model__learning_rate=0.3, model__max_depth=7, model__n_estimators=200; total time=   9.1s
# [CV] END model__learning_rate=0.3, model__max_depth=7, model__n_estimators=250; total time=  12.1s
# [CV] END model__learning_rate=0.3, model__max_depth=7, model__n_estimators=250; total time=  11.6s
# [CV] END model__learning_rate=0.3, model__max_depth=7, model__n_estimators=250; total time=  11.1s
# [CV] END model__learning_rate=0.3, model__max_depth=7, model__n_estimators=300; total time=  14.1s
# [CV] END model__learning_rate=0.3, model__max_depth=7, model__n_estimators=300; total time=  13.8s
# [CV] END model__learning_rate=0.3, model__max_depth=7, model__n_estimators=300; total time=  12.4s
# [CV] END model__learning_rate=0.3, model__max_depth=11, model__n_estimators=100; total time=   9.0s
# [CV] END model__learning_rate=0.3, model__max_depth=11, model__n_estimators=100; total time=   9.0s
# [CV] END model__learning_rate=0.3, model__max_depth=11, model__n_estimators=100; total time=   8.8s
# [CV] END model__learning_rate=0.3, model__max_depth=11, model__n_estimators=200; total time=  15.8s
# [CV] END model__learning_rate=0.3, model__max_depth=11, model__n_estimators=200; total time=  15.3s
# [CV] END model__learning_rate=0.3, model__max_depth=11, model__n_estimators=200; total time=  22.0s
# [CV] END model__learning_rate=0.3, model__max_depth=11, model__n_estimators=250; total time=  19.8s
# [CV] END model__learning_rate=0.3, model__max_depth=11, model__n_estimators=250; total time=  19.0s
# [CV] END model__learning_rate=0.3, model__max_depth=11, model__n_estimators=250; total time=  18.6s
# [CV] END model__learning_rate=0.3, model__max_depth=11, model__n_estimators=300; total time=  22.9s
# [CV] END model__learning_rate=0.3, model__max_depth=11, model__n_estimators=300; total time=  22.1s
# [CV] END model__learning_rate=0.3, model__max_depth=11, model__n_estimators=300; total time=  21.4s
# [CV] END model__learning_rate=0.3, model__max_depth=13, model__n_estimators=100; total time=  10.9s
# [CV] END model__learning_rate=0.3, model__max_depth=13, model__n_estimators=100; total time=  10.5s
# [CV] END model__learning_rate=0.3, model__max_depth=13, model__n_estimators=100; total time=  10.8s
# [CV] END model__learning_rate=0.3, model__max_depth=13, model__n_estimators=200; total time=  26.4s
# [CV] END model__learning_rate=0.3, model__max_depth=13, model__n_estimators=200; total time=  28.2s
# [CV] END model__learning_rate=0.3, model__max_depth=13, model__n_estimators=200; total time=  25.1s
# [CV] END model__learning_rate=0.3, model__max_depth=13, model__n_estimators=250; total time=  24.4s
# [CV] END model__learning_rate=0.3, model__max_depth=13, model__n_estimators=250; total time=  31.7s
# [CV] END model__learning_rate=0.3, model__max_depth=13, model__n_estimators=250; total time=  34.7s
# [CV] END model__learning_rate=0.3, model__max_depth=13, model__n_estimators=300; total time=  47.8s
# [CV] END model__learning_rate=0.3, model__max_depth=13, model__n_estimators=300; total time=  33.3s
# [CV] END model__learning_rate=0.3, model__max_depth=13, model__n_estimators=300; total time=  34.7s
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('tfidf', TfidfVectorizer()),
#                                        ('model',
#                                         XGBClassifier(base_score=None,
#                                                       booster=None,
#                                                       callbacks=None,
#                                                       colsample_bylevel=None,
#                                                       colsample_bynode=None,
#                                                       colsample_bytree=None,
#                                                       device=None,
#                                                       early_stopping_rounds=None,
#                                                       enable_categorical=False,
#                                                       eval_metric=None,
#                                                       feature_types=None,
#                                                       feature_weights=None,
#                                                       gamma=None,
#                                                       grow_policy=...
#                                                       max_cat_threshold=None,
#                                                       max_cat_to_onehot=None,
#                                                       max_delta_step=None,
#                                                       max_depth=None,
#                                                       max_leaves=None,
#                                                       min_child_weight=None,
#                                                       missing=nan,
#                                                       monotone_constraints=None,
#                                                       multi_strategy=None,
#                                                       n_estimators=None,
#                                                       n_jobs=None,
#                                                       num_parallel_tree=None, ...))]),
#              param_grid={'model__learning_rate': [0.1, 0.01, 0.3],
#                          'model__max_depth': [3, 5, 7, 11, 13],
#                          'model__n_estimators': [100, 200, 250, 300]},
#              verbose=2)

# %%
print("Best Parameters:", final_model.best_params_)
print(classification_report(y, final_model.predict(X)))
# Out:
# Best Parameters: {'model__learning_rate': 0.3, 'model__max_depth': 3, 'model__n_estimators': 250}
#               precision    recall  f1-score   support
#
#            0       0.84      0.95      0.89      4342
#            1       0.92      0.76      0.83      3271
#
#     accuracy                           0.87      7613
#    macro avg       0.88      0.86      0.86      7613
# weighted avg       0.88      0.87      0.87      7613

# %%
df_sub = pd.read_csv('sample_submission.csv')
y_pred = final_model.predict(df_test['text'])
df_sub['target'] = y_pred
df_sub.to_csv('submission1.csv', index=False)

# %% [markdown]
# # TfidfVectorizer + LogisticRegression

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import f1_score
from sklearn.metrics import classification_report

# %%
X = df_train['text']
y = df_train['target']

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, random_state=40)

# %%
pipe = Pipeline([
    ('tfidf', TfidfVectorizer(max_features=10000, ngram_range=(1, 2), sublinear_tf = True)),
    ('model', LogisticRegression(class_weight='balanced',  penalty = 'l2', C = 1.0, solver = 'liblinear', max_iter=10000, ))
])

# %%
param_grid = {
    'tfidf__max_features': [5000],
    'tfidf__ngram_range': [(1,1), (1,2)],
    'model__C': [0.5, 1.0],
    'model__class_weight': ['balanced']
}

# %%
grid = GridSearchCV(pipe, param_grid, scoring='f1', cv=3, verbose=1, n_jobs=-1)
grid.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('tfidf',
#                                         TfidfVectorizer(max_features=10000,
#                                                         ngram_range=(1, 2),
#                                                         sublinear_tf=True)),
#                                        ('model',
#                                         LogisticRegression(class_weight='balanced',
#                                                            max_iter=10000,
#                                                            solver='liblinear'))]),
#              n_jobs=-1,
#              param_grid={'model__C': [0.5, 1.0],
#                          'model__class_weight': ['balanced'],
#                          'tfidf__max_features': [5000],
#                          'tfidf__ngram_range': [(1, 1), (1, 2)]},
#              scoring='f1', verbose=1)

# %%
y_pred = grid.predict(X_val)

# %%
f1_score(y_val, y_pred)
# Out:
# 0.7750188111361926

# %%
print(classification_report(y_val, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.83      0.83       852
#            1       0.78      0.77      0.78       671
#
#     accuracy                           0.80      1523
#    macro avg       0.80      0.80      0.80      1523
# weighted avg       0.80      0.80      0.80      1523

# %%
df_sub = pd.read_csv('sample_submission.csv')
y_pred = grid.predict(df_test['text'])
df_sub['target'] = y_pred
df_sub.to_csv('submission2.csv', index=False)
